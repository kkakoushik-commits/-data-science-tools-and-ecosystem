# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# Datascienceecosystem
# #Data Science Tools
# and Ecosystem
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# some of the popular languages that Data Scientists use are:
#
# 1. python
# 2. R
# 3. SQL

# %% [markdown]
# some of the commonly used
# libraries used by Data Scientists
# include:
#
# 1. **pandas** (for data manipulation and analysis)
# 2. **NumPy** (for numerical operations and array processing)
# 3. **Matplotlib** (for Data visualization)
# 4. **Scikit-learn** (for machine learning algorithms)

# %% [markdown]
# | Data Science Tools  |
# | :--- |
# | Jupyter Notebook  |
# | Apache spark  |

# %% [markdown]
# ### Below are a few examples of evaluating arthimetic expressions in python.

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
# This a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes into hours by diving by 60.
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# * List popular languages for Data Science
# * Describe the use of various Data Science libraries
# * Understand the concept of a code kernel
# * perform basic artihmetic operations in python

# %% [markdown]
# # # Author (Lakshmi Holla)
